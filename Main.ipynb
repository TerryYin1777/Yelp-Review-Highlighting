# %%
DEFINES_ONLY = True

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  1 15:00:40 2017

@author: He Song
"""

from bs4 import BeautifulSoup
import time
import requests

def reviews(url,type,name):
    count=0;
    restname=[]
    fw=open(name,'w') # output file
    for p in range(1,80):
        pageLink=url+'/search?find_loc=Los+Angeles,+CA&start='+str(p*10)+'&cflt=' +type# make the page url
        for i in range(5): # try 5 times
                    try:
                        #use the browser to access the url
                        response=requests.get(pageLink,headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36', })
                        html=response.content # get the html
                        break # we got the file, break the loops
                    except Exception as e:# browser.open() threw an exception, the attempt to get the response failed
                        print ('failed attempt',i)
                        time.sleep(2) # wait 2 secs
        				
        		
        if not html:continue # couldnt get the page, ignore
                
        soup = BeautifulSoup(html.decode('ascii', 'ignore'),'lxml') # parse the html 
        divget=soup.findAll('div',{'class':'media-story'})
        
        for div in divget:
            #print(review)
            #print(div)
            try:
                restaurant=div.find('a', {'class':'biz-name js-analytics-click'}) # get all the review divs
                kind=div.find('span',{'class':'category-str-list'})
                #print(restaurant)
               
                if restaurant:
                    if 'ad_business_id' not in restaurant['href']:
                        kind_s=kind.findAll('a')
                        if len(kind_s)==1:
                            
                            reviewnum=div.find('span',{'class':'review-count rating-qualifier'})
                            
                            reviewnum=reviewnum.text.replace('reviews','')
                            reviewnum=reviewnum.replace(' ','')
                           
                            if float(reviewnum)>200 and count<=50:
                                #print(kind)
                                print(reviewnum)
                                nextse=restaurant['href']
                                print(nextse)
                                sp=restaurant.find('span')
                                print(sp.text)
                                if sp.text not in restname:
                                    fw.write(str(count)+'\t'+reviewnum+'\t'+nextse+'\t'+sp.text+'\n')
                                    restname.append(sp.text)
                                    count+=1
                                print('\n')
                                    
                            elif count>50 :
                                fw.close()
                                return
            except Exception as e:
                continue

if DEFINES_ONLY == False:
    reviews('https://www.yelp.com', 'chinese', 'chinese.txt')

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  1 15:00:40 2017

@author: Y. Zhao
"""

import time
import requests
import os, shutil

def getReviews(urlBase, url, filepath, maxReviews = 300):
    for p in range(0, int(maxReviews / 20)):
        pageLink=urlBase + url + '?start=' + str(p * 20) + '&sort_by=date_desc'# make the page url
        for i in range(5): # try 5 times
            try:
                #use the browser to access the url
                response=requests.get(pageLink,headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36', })
                html=response.content # get the html
                break # we got the file, break the loops
            except Exception as e:# browser.open() threw an exception, the attempt to get the response failed
                print ('failed attempt',i)
                time.sleep(2) # wait 2 secs


        if not html:
            raise Exception()
            continue # couldnt get the page, ignore
        else:
            with open(filepath + '/' + str(p) + '.html', 'w') as f:
                f.write(html.decode('ascii', 'ignore'))


#reviews('https://www.yelp.com', '/biz/lao-sze-chuan-glendale-5')

def getGene(name, maxReviews = 300):
    with open(name + '.txt', 'r') as f:
        ls = f.readlines()
        print(int(len(ls) / 3))
        for i in range(0, len(ls), 3):
            id = ls[i].strip()
            path = ls[i + 2].strip().split('\t')[0]
            print(id + " " + ls[i + 2].strip().split('\t')[1])
            if os.path.exists(os.path.join(os.getcwd(), name + "_" + id)) == False:
                try:
                    os.mkdir(os.path.join(os.getcwd(), 'temp'))
                except FileExistsError as e:
                    shutil.rmtree(os.path.join(os.getcwd(), 'temp/'))
                    os.mkdir(os.path.join(os.getcwd(), 'temp'))
                try:
                    getReviews('https://www.yelp.com', path, os.path.join(os.getcwd(), 'temp'), maxReviews = 300)
                    with open(os.path.join(os.getcwd(), 'temp') + '/metadata', 'w') as f:
                        f.write(ls[i] + ls[i + 1] + ls[i + 2] + str(int(maxReviews / 20)) + '\n')
                    os.rename(os.path.join(os.getcwd(), 'temp'), os.path.join(os.getcwd(), name + "_" + id))
                except Exception as e:
                    print ('failed attempt', name + "_" + id)
                    continue
            
if DEFINES_ONLY == False:
    getGene('chinese')

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  1 15:00:40 2017

@author: Yi Zhao
"""

from bs4 import BeautifulSoup
import re
import time
import requests
import pandas as pd
import os

def get1(div_review, classdesc):
    try:
        li_friends = div_review.findAll('li', {'class': classdesc})
        li_friends_b = li_friends[0].findAll('b')
        friends = li_friends_b[0].contents[0]
        return friends
    except:
        return 0


def analyseHtml(html, rId):
    results = []
    print(rId)

    soup = BeautifulSoup(html,'lxml') # parse the html 
    reviews=soup.findAll('div',{'class':'review review--with-sidebar'})
    
    for div_review in reviews:
        result = {'restaurantId': rId}
        
        review_id = div_review['data-review-id']
        result['review_id'] = review_id

        try:
            a_username = div_review.findAll('a', {'class': 'user-display-name js-analytics-click'})
            username = a_username[0].contents[0]
            result['username'] = username
        except IndexError:
            result['username'] = ''
        
        num_friends = get1(div_review, 'friend-count responsive-small-display-inline-block')
        result['num_friends'] = num_friends
        num_reviews = get1(div_review, 'review-count responsive-small-display-inline-block')
        result['num_reviews'] = num_reviews
        num_photos = get1(div_review, 'photo-count responsive-small-display-inline-block')
        result['num_photos'] = num_photos
        
        try:
            review_text = div_review.findAll('p', {'lang': 'en'})[0].contents[0]
            result['review_text'] = review_text
        except IndexError:
            result['review_text'] = ''
        
        rating_qualifier = div_review.findAll('span', {'class': 'rating-qualifier'})[0].contents[0]
        result['date'] = rating_qualifier.strip()
        
        elite = len(div_review.findAll('a', {'href': '/elite'}))
        result['elite'] = elite
        
        try:
            a_useful = div_review.findAll('class', {'ybtn ybtn--small useful js-analytics-click'})[0]
            span_useful = a_useful.findAll('span', {'class': 'count'})[0]
            useful = span_useful.contents[0]
            result['useful'] = useful
        except IndexError:
            result['useful'] = 0
        
        rating = div_review.findAll('div', {'class': 'rating-large'})[0]['title']
        result['rating'] = rating.split()[0]
    
        results.append(result)
        
    return results

def analyseDir(path, rId):
    csvfilepath = os.path.join(path, 'data.csv')
    if os.path.isfile(csvfilepath) == True:
        return pd.read_csv(csvfilepath)
    else:
        res = []
        tempfilepath = 'temp.csv'
        f = open(os.path.join(path, 'metadata'))
        pages = int(f.readlines()[3])
        for page in range(pages):
            res += analyseHtml(open(os.path.join(path, str(page) + '.html')).read(), rId)
        df2 = pd.DataFrame(res)
        df2.to_csv(tempfilepath)
        os.rename(tempfilepath, csvfilepath)
        return df2

def analyseGene(name, max_id, path='/Users/enyaning/Desktop/BIA660/BIA660_TEAM_2/'):
    dfs = []
    for id in range(max_id + 1):
        df = analyseDir(path + name + '_' + str(id), name + '_' + str(id))
        dfs.append(df)
    return pd.concat(dfs)

def main(name, max_id, path):
    df2 = analyseGene(name, max_id, path=path)
    df2.to_csv(name + '.csv')
    return df2

if DEFINES_ONLY == False:
    main('chinese', 50, '/Users/enyaning/Desktop/BIA660/BIA660_TEAM_2/')

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  8 14:39:07 2017

@author: enyaning
"""


import pandas as pd
import re
import operator
from nltk.corpus import stopwords

import nltk
from nltk.util import ngrams
from nltk.tokenize import sent_tokenize
from nltk import load

from textblob import TextBlob

def getFreq(inputcsv, outputcsv):
    csv_path = inputcsv
    data = pd.read_csv(csv_path)

    wordcount = {}
    stop_words =  set(stopwords.words('english'))
    costumer_stop_words = ['chinese', 'italian', 'mexican', 'good', 'great', 'food', 'place', 'los', 'angeles', 'hoboken']
    for word in costumer_stop_words: stop_words.add(word)
    costumer_not_stop_words = []
    for word in costumer_not_stop_words: stop_words.discard(word)
    file_stop_words = [word.strip().lower() for word in open('stopwords.txt').readlines()]

    #make a new tagger
    _POS_TAGGER = 'taggers/maxent_treebank_pos_tagger/english.pickle'
    tagger = load(_POS_TAGGER)


    jsons = []

    review_number = 0
    for index, row in data.iterrows():
        try:
            review = row['review_text']
            restaurantId = row['restaurantId']

            blob = TextBlob(review)
            blob.noun_phrases

            for i in range(len(blob.sentences)):
                sentence = blob.sentences[i]

                terms = nltk.word_tokenize(sentence.raw.lower())
                tagged_terms=tagger.tag(terms)

                for tg in ngrams(tagged_terms,2):
                    if tg[0][1].startswith('NN') and tg[1][1].startswith('NN') and tg[0][0] not in stop_words and tg[1][0] not in stop_words:
                        key = tg[0][0] + " " + tg[1][0]
                        json = {
                            "restaurantId": restaurantId,
                            "review_id": index,
                            "sentence_id": i,
                            "sentence": sentence.raw,
                            "phrase": key
                        }
                        jsons.append(json)

        except TypeError:
            print("TypeError");
        finally:
            if review_number%20 == 0:
                print(review_number)
            review_number += 1

    df = pd.DataFrame(jsons)
    df.to_csv('test.csv')
    print(df)
    
if DEFINES_ONLY == False:
    getFreq('chinese.csv', 'test.csv')

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  8 14:39:07 2017

@author: enyaning
"""


import pandas as pd
import json

def toJson(inputcsv, outputjson, restaurantDictName):
    csv_path = inputcsv
    data = pd.read_csv(csv_path)

    reduce1 = {}
    print('reducing 1')

    for index, row in data.iterrows():
        key = str(row['restaurantId']) + "|" + row['phrase'] + "|" + str(row['review_id']) 
        if key not in reduce1:
            reduce1[key] = []
        reduce1[key].append(row['sentence'])

    reduce2 = {}
    print('reducing 2')

    for k, v in reduce1.items():
        parts = k.split("|")
        key = parts[0] + "|" + parts[1] # restaurantId | phrase
        if key not in reduce2:
            reduce2[key] = []
        reduce2[key].append({'review_id': parts[2], 'sentences': v})

    reduce3 = {}
    print('reducing 3')

    for k, v in reduce2.items():
        parts = k.split("|")
        key = parts[0] # restaurantId
        if key not in reduce3:
            reduce3[key] = []
        reduce3[key].append({'phrase': parts[1], 'reviews': v})

    def sort_top_100(arr):
        return sorted(arr, key = lambda k: len(k['reviews']), reverse=True)[:100]

    print('finally')

    dictIdName = {}
    i = 0
    for l in open(restaurantDictName + '.txt').readlines():
        parts = l.split('\t')
        print(l, parts)
        if(len(parts) == 3):
            dictIdName[restaurantDictName + '_' + str(i)] = parts[2]
            i += 1
    
    res = []
    for k, v in reduce3.items():
        res.append({'restaurantId': k, 'restaurantName': dictIdName[k], 'top-none-phrases': sort_top_100(v)})

    with open(outputjson, 'w') as f:
        json.dump(res, f, indent=4, sort_keys=True)

    return res

# DEFINES_ONLY = False
DEFINES_ONLY = True
if DEFINES_ONLY == False:
    toJson('test.csv', 'json.json', 'customer')

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Dec  2 14:32:59 2017

@author: hasee
"""
from textblob import TextBlob
import json

def getresult(inputjson, outputfile):
    d = {}
    with open(inputjson) as json_data:
        d=json.load(json_data)

    dictIdName = {}
    i = 0
    for l in open('chinese' + '.txt').readlines():
        parts = l.split('\t')
        print(l, parts)
        if(len(parts) == 3):
            dictIdName['chinese' + '_' + str(i)] = parts[2]
            i += 1

    for restaurant in d: #[0:5]:
        outputfile.write('\n')
        outputfile.write(dictIdName[restaurant['restaurantId']])
#         outputfile.write(restaurant['restaurantName'] + '\n')
        likes=[]
        dislikes=[]
        for topword in restaurant['top-none-phrases'][0:10]:

            scoreword=0
    #        print(topword['phrase'])
            for reviews in topword['reviews']:
                countse=0
                scorese=0;
                for sentence in reviews['sentences']:
                    sentence=sentence.replace('chicken','beef')
                    blob = TextBlob(sentence)
                    blob.tags
                    blob.noun_phrases
                    ns=blob.sentences[0].sentiment.polarity
                    scorese+=ns
    #                print(sentence)
    #                print(ns)
                    countse+=1;
                scoreword+=scorese/countse
            result_word_score_avg=scoreword/len(topword['reviews'])
            if result_word_score_avg>0:
                likes.append(topword['phrase'])
            else:
                dislikes.append(topword['phrase'])
    #        print(result_word_score_avg)
        outputfile.write('What the Guests loved Most: ' + '\n')
        for like in likes:
            outputfile.write(like + '\n')
        outputfile.write('\n')
        outputfile.write('What nedd to be improved: ' + '\n')
        for dislike in dislikes:
            outputfile.write(dislike + '\n')
        outputfile.write('\n')
        outputfile.write('\n')
    
if DEFINES_ONLY == False:
    getresult('json.json', sys.stdout)

# %%
import sys

def customerRestaurant(url, name):
    open('customer.txt', 'w').write('0\n300\n\t' + url + '\t' + name + '\n')
    getGene('customer')
    main('customer', 0, '/Users/tylio/660/BIA660_TEAM_2/')
    getFreq('customer.csv', 'test.csv')
    toJson('test.csv', 'json.json', 'customer')
    getresult('json.json', sys.stdout)

def runGene(geneName):
    reviews('https://www.yelp.com', geneName, geneName + '.txt')
    getGene(geneName)
    main(geneName, 50, '/Users/tylio/660/BIA660_TEAM_2/')
    getFreq(geneName + '.csv', 'test.csv')
    toJson('test.csv', 'json.json', geneName)
    getresult('json.json', sys.stdout)
    
if DEFINES_ONLY == False:
    runGene('chinese')
    customerRestaurant('/biz/king-szechuan-palace-jersey-city', 'King Szechuan Palace')

# %%
runGene('italian')
# Out:
# 814
#
# /biz/il-capriccio-on-vermont-los-angeles
# Il Capriccio on Vermont
#
#
#
# 714
#
# /biz/pomodoro-trattoria-los-angeles-2
# Pomodoro Trattoria
#
#
#
# 488
#
# /biz/speranza-los-angeles
# Speranza
#
#
#
# 298
#
# /biz/frankies-los-angeles-2
# Frankies
#
#
#
# 1001
#
# /biz/the-factory-kitchen-los-angeles
# The Factory Kitchen
#
#
#
# 1382
#
# /biz/drago-centro-los-angeles
# DRAGO Centro
#
#
#
# 455
#
# /biz/pizzicotto-los-angeles
# Pizzicotto
#
#
#
# 562
#
# /biz/spumoni-restaurant-sherman-oaks
# Spumoni Restaurant
#
#
#
# 1382
#
# /biz/drago-centro-los-angeles
# DRAGO Centro
#
#
#
# 726
#
# /biz/fabiolus-cucina-hollywood
# Fabiolus Cucina
#
#
#
# 879
#
# /biz/gales-pasadena
# Gales
#
#
#
# 637
#
# /biz/madeo-restaurant-los-angeles-3
# Madeo Restaurant
#
#
#
# 391
#
# /biz/gusto-los-angeles
# Gusto
#
#
#
# 259
#
# /biz/centanni-trattoria-burbank
# Centanni Trattoria
#
#
#
# 249
#
# /biz/cafe-angelino-los-angeles
# Cafe Angelino
#
#
#
# 677
#
# /biz/la-tavolata-artesia
# La Tavolata
#
#
#
# 775
#
# /biz/raffaello-ristorante-san-pedro
# Raffaello Ristorante
#
#
#
# 877
#
# /biz/jon-and-vinnys-los-angeles
# Jon & Vinnys
#
#
#
# 641
#
# /biz/ca-del-sole-toluca-lake-2
# Ca Del Sole
#
#
#
# 423
#
# /biz/locanda-veneta-los-angeles
# Locanda Veneta
#
#
#
# 423
#
# /biz/locanda-veneta-los-angeles
# Locanda Veneta
#
#
#
# 260
#
# /biz/enzo-and-angela-los-angeles-2
# Enzo & Angela
#
#
#
# 344
#
# /biz/italys-little-kitchen-los-angeles
# Italys Little Kitchen
#
#
#
# 677
#
# /biz/la-tavolata-artesia
# La Tavolata
#
#
#
# 1344
#
# /biz/c-and-o-cucina-marina-del-rey
# C & O Cucina
#
#
#
# 434
#
# /biz/chi-spacca-los-angeles
# Chi Spacca
#
#
#
# 214
#
# /biz/spartina-los-angeles
# Spartina
#
#
#
# 247
#
# /biz/ancora-cucina-italiana-tarzana
# Ancora Cucina Italiana
#
#
#
# 275
#
# /biz/north-italia-santa-monica-3
# North Italia
#
#
#
# 495
#
# /biz/romano-cucina-sunset-beach-2
# Romano Cucina
#
#
#
# 207
#
# /biz/palmeri-ristorante-los-angeles
# Palmeri Ristorante
#
#
#
# 333
#
# /biz/brunos-santa-monica
# Brunos
#
#
#
# 950
#
# /biz/trattoria-amici-glendale-2
# Trattoria Amici
#
#
#
# 259
#
# /biz/centanni-trattoria-burbank
# Centanni Trattoria
#
#
#
# 641
#
# /biz/ca-del-sole-toluca-lake-2
# Ca Del Sole
#
#
#
# 372
#
# /biz/via-veneto-santa-monica
# Via Veneto
#
#
#
# 726
#
# /biz/fabiolus-cucina-hollywood
# Fabiolus Cucina
#
#
#
# 276
#
# /biz/novecento-pasta-and-grill-culver-city
# Novecento Pasta & Grill
#
#
#
# 265
#
# /biz/adagio-ristorante-woodland-hills
# Adagio Ristorante
#
#
#
# 238
#
# /biz/buon-gusto-ristorante-mission-hills
# Buon Gusto Ristorante
#
#
#
# 303
#
# /biz/divina-cucina-montrose
# Divina Cucina
#
#
#
# 464
#
# /biz/il-tramezzino-beverly-hills-beverly-hills
# Il Tramezzino - Beverly Hills
#
#
#
# 394
#
# /biz/via-alloro-beverly-hills-2
# Via Alloro
#
#
#
# 271
#
# /biz/la-cava-san-fernando-valley
# La Cava
#
#
#
# 237
#
# /biz/betos-simi-valley
# Betos
#
#
#
# 247
#
# /biz/ancora-cucina-italiana-tarzana
# Ancora Cucina Italiana
#
#
#
# 529
#
# /biz/ago-restaurant-west-hollywood
# AGO Restaurant
#
#
#
# 434
#
# /biz/vino-and-cucina-long-beach
# Vino & Cucina
#
#
#
# 254
#
# /biz/trastevere-hollywood-2
# Trastevere
#
#
#
# 394
#
# /biz/via-alloro-beverly-hills-2
# Via Alloro
#
#
#
# 279
#
# /biz/picarellis-cucina-italiana-long-beach-3
# Picarellis Cucina Italiana
#
#
#
# 254
#
# /biz/trastevere-hollywood-2
# Trastevere
#
#
#
# 422
#
# /biz/la-scala-beverly-hills-2
# La Scala
#
#
#
# 361
#
# /biz/il-ristorante-di-giorgio-baldi-santa-monica
# Il Ristorante di Giorgio Baldi
#
#
#
# 245
#
# /biz/mangiamo-ristorante-and-bar-manhattan-beach
# Mangiamo Ristorante & Bar
#
#
#
# 351
#
# /biz/capo-santa-monica
# Capo
#
#
#
# 412
#
# /biz/valentino-santa-monica
# Valentino
#
#
#
# 677
#
# /biz/la-tavolata-artesia
# La Tavolata
#
#
#
# 222
#
# /biz/locanda-portofino-santa-monica-2
# Locanda Portofino
#
#
#
# 555
#
# /biz/trastevere-santa-monica
# Trastevere
#
#
#
# 222
#
# /biz/locanda-portofino-santa-monica-2
# Locanda Portofino
#
#
#
# 213
#
# /biz/the-bottle-inn-hermosa-hermosa-beach
# The Bottle Inn Hermosa
#
#
#
# 325
#
# /biz/francos-italian-restaurant-cypress
# Francos Italian Restaurant
#
#
# 51
# 0 Il Capriccio on Vermont
# 1 Pomodoro Trattoria
# 2 Speranza
# 3 Frankies
# 4 The Factory Kitchen
# 5 DRAGO Centro
# 6 Pizzicotto
# 7 Spumoni Restaurant
# 8 Fabiolus Cucina
# 9 Gales
# 10 Madeo Restaurant
# 11 Gusto
# 12 Centanni Trattoria
# 13 Cafe Angelino
# 14 La Tavolata
# 15 Raffaello Ristorante
# 16 Jon & Vinnys
# 17 Ca Del Sole
# 18 Locanda Veneta
# 19 Enzo & Angela
# 20 Italys Little Kitchen
# 21 C & O Cucina
# 22 Chi Spacca
# 23 Spartina
# 24 Ancora Cucina Italiana
# 25 North Italia
# 26 Romano Cucina
# 27 Palmeri Ristorante
# 28 Brunos
# 29 Trattoria Amici
# 30 Via Veneto
# 31 Novecento Pasta & Grill
# 32 Adagio Ristorante
# 33 Buon Gusto Ristorante
# 34 Divina Cucina
# 35 Il Tramezzino - Beverly Hills
# 36 Via Alloro
# 37 La Cava
# 38 Betos
# 39 AGO Restaurant
# 40 Vino & Cucina
# 41 Trastevere
# 42 Picarellis Cucina Italiana
# 43 La Scala
# 44 Il Ristorante di Giorgio Baldi
# 45 Mangiamo Ristorante & Bar
# 46 Capo
# 47 Valentino
# 48 Locanda Portofino
# 49 The Bottle Inn Hermosa
# 50 Francos Italian Restaurant
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_0
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_1
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_2
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_3
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_4
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_5
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_6
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_7
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_8
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_9
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_10
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_11
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_12
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_13
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_14
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_15
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_16
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_17
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_18
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_19
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_20
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_21
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_22
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_23
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_24
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_25
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_26
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_27
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_28
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_29
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_30
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_31
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_32
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_33
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_34
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_35
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_36
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_37
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_38
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_39
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_40
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_41
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_42
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_43
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_44
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_45
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_46
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_47
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_48
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_49
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# italian_50
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# 3000
# 3020
# 3040
# 3060
# 3080
# 3100
# 3120
# 3140
# 3160
# 3180
# 3200
# 3220
# 3240
# 3260
# 3280
# 3300
# 3320
# 3340
# 3360
# 3380
# 3400
# 3420
# 3440
# 3460
# 3480
# 3500
# 3520
# 3540
# 3560
# 3580
# 3600
# 3620
# 3640
# 3660
# 3680
# 3700
# 3720
# 3740
# 3760
# 3780
# 3800
# 3820
# 3840
# 3860
# 3880
# 3900
# 3920
# 3940
# 3960
# 3980
# 4000
# 4020
# 4040
# 4060
# 4080
# 4100
# 4120
# 4140
# 4160
# 4180
# 4200
# 4220
# 4240
# 4260
# 4280
# 4300
# 4320
# 4340
# 4360
# 4380
# 4400
# 4420
# 4440
# 4460
# 4480
# 4500
# 4520
# 4540
# 4560
# 4580
# 4600
# 4620
# 4640
# 4660
# 4680
# 4700
# 4720
# 4740
# 4760
# 4780
# 4800
# 4820
# 4840
# 4860
# 4880
# 4900
# 4920
# 4940
# 4960
# 4980
# 5000
# 5020
# 5040
# 5060
# 5080
# 5100
# 5120
# 5140
# 5160
# 5180
# 5200
# 5220
# 5240
# 5260
# 5280
# 5300
# 5320
# 5340
# 5360
# 5380
# 5400
# 5420
# 5440
# 5460
# 5480
# 5500
# 5520
# 5540
# 5560
# 5580
# 5600
# 5620
# 5640
# 5660
# 5680
# 5700
# 5720
# 5740
# 5760
# 5780
# 5800
# 5820
# 5840
# 5860
# 5880
# 5900
# 5920
# 5940
# 5960
# 5980
# 6000
# 6020
# 6040
# 6060
# 6080
# 6100
# 6120
# 6140
# 6160
# 6180
# 6200
# 6220
# 6240
# 6260
# 6280
# 6300
# 6320
# 6340
# 6360
# 6380
# 6400
# 6420
# 6440
# 6460
# 6480
# 6500
# 6520
# 6540
# 6560
# 6580
# 6600
# 6620
# 6640
# 6660
# 6680
# 6700
# 6720
# 6740
# 6760
# 6780
# 6800
# 6820
# 6840
# 6860
# 6880
# 6900
# 6920
# 6940
# 6960
# 6980
# 7000
# 7020
# 7040
# 7060
# 7080
# 7100
# 7120
# 7140
# 7160
# 7180
# 7200
# 7220
# 7240
# 7260
# 7280
# 7300
# 7320
# 7340
# 7360
# 7380
# 7400
# 7420
# 7440
# 7460
# 7480
# 7500
# 7520
# 7540
# 7560
# 7580
# 7600
# 7620
# 7640
# 7660
# 7680
# 7700
# 7720
# 7740
# 7760
# 7780
# 7800
# 7820
# 7840
# 7860
# 7880
# 7900
# 7920
# 7940
# 7960
# 7980
# 8000
# 8020
# 8040
# 8060
# 8080
# 8100
# 8120
# 8140
# 8160
# 8180
# 8200
# 8220
# 8240
# 8260
# 8280
# 8300
# 8320
# 8340
# 8360
# 8380
# 8400
# 8420
# 8440
# 8460
# 8480
# 8500
# 8520
# 8540
# 8560
# 8580
# 8600
# 8620
# 8640
# 8660
# 8680
# 8700
# 8720
# 8740
# 8760
# 8780
# 8800
# 8820
# 8840
# 8860
# 8880
# 8900
# 8920
# 8940
# 8960
# 8980
# 9000
# 9020
# 9040
# 9060
# 9080
# 9100
# 9120
# 9140
# 9160
# 9180
# 9200
# 9220
# 9240
# 9260
# 9280
# 9300
# 9320
# 9340
# 9360
# 9380
# 9400
# 9420
# 9440
# 9460
# 9480
# 9500
# 9520
# 9540
# 9560
# 9580
# 9600
# 9620
# 9640
# 9660
# 9680
# 9700
# 9720
# 9740
# 9760
# 9780
# 9800
# 9820
# 9840
# 9860
# 9880
# 9900
# 9920
# 9940
# 9960
# 9980
# 10000
# 10020
# 10040
# 10060
# 10080
# 10100
# 10120
# 10140
# 10160
# 10180
# 10200
# 10220
# 10240
# 10260
# 10280
# 10300
# 10320
# 10340
# 10360
# 10380
# 10400
# 10420
# 10440
# 10460
# 10480
# 10500
# 10520
# 10540
# 10560
# 10580
# 10600
# 10620
# 10640
# 10660
# 10680
# 10700
# 10720
# 10740
# 10760
# 10780
# 10800
# 10820
# 10840
# 10860
# 10880
# 10900
# 10920
# 10940
# 10960
# 10980
# 11000
# 11020
# 11040
# 11060
# 11080
# 11100
# 11120
# 11140
# 11160
# 11180
# 11200
# 11220
# 11240
# 11260
# 11280
# 11300
# 11320
# 11340
# 11360
# 11380
# 11400
# 11420
# 11440
# 11460
# 11480
# 11500
# 11520
# 11540
# 11560
# 11580
# 11600
# 11620
# 11640
# 11660
# 11680
# 11700
# 11720
# 11740
# 11760
# 11780
# 11800
# 11820
# 11840
# 11860
# 11880
# 11900
# 11920
# 11940
# 11960
# 11980
# 12000
# 12020
# 12040
# 12060
# 12080
# 12100
# 12120
# 12140
# 12160
# 12180
# 12200
# 12220
# 12240
# 12260
# 12280
# 12300
# 12320
# 12340
# 12360
# 12380
# 12400
# 12420
# 12440
# 12460
# 12480
# 12500
# 12520
# 12540
# 12560
# 12580
# 12600
# 12620
# 12640
# 12660
# 12680
# 12700
# 12720
# 12740
# 12760
# 12780
# 12800
# 12820
# 12840
# 12860
# 12880
# 12900
# 12920
# 12940
# 12960
# 12980
# 13000
# 13020
# 13040
# 13060
# 13080
# 13100
# 13120
# 13140
# 13160
# 13180
# 13200
# 13220
# 13240
# 13260
# 13280
# 13300
# 13320
# 13340
# 13360
# 13380
# 13400
# 13420
# 13440
# 13460
# 13480
# 13500
# 13520
# 13540
# 13560
# 13580
# 13600
# 13620
# 13640
# 13660
# 13680
# 13700
# 13720
# 13740
# 13760
# 13780
# 13800
# 13820
# 13840
# 13860
# 13880
# 13900
# 13920
# 13940
# 13960
# 13980
# 14000
# 14020
# 14040
# 14060
# 14080
# 14100
# 14120
# 14140
# 14160
# 14180
# 14200
# 14220
# 14240
# 14260
# 14280
# 14300
# 14320
# 14340
# 14360
# 14380
# 14400
# 14420
# 14440
# 14460
# 14480
#                         phrase restaurantId  review_id  \
# 0                  goat cheese    italian_0          0
# 1            excellent service    italian_0          1
# 2                     el dente    italian_0          2
# 3                 crappy owner    italian_0          3
# 4              wednesday night    italian_0          4
# 5             ravioli aragosta    italian_0          4
# 6                     yr mouth    italian_0          4
# 7                tuesday night    italian_0          5
# 8                greek theater    italian_0          5
# 9              theater concert    italian_0          5
# 10              homemade bread    italian_0          6
# 11            rigatoni antonio    italian_0          6
# 12          gorgonzola chicken    italian_0          8
# 13                  pasta alla    italian_0         11
# 14                alla norcina    italian_0         11
# 15                   zuppa del    italian_0         11
# 16                  del giorno    italian_0         11
# 17               mushroom soup    italian_0         11
# 18                  pasta alla    italian_0         11
# 19                alla norcina    italian_0         11
# 20                tomato sauce    italian_0         11
# 21               sauce thicker    italian_0         11
# 22               pasta fagioli    italian_0         16
# 23                 lame excuse    italian_0         18
# 24                cheese salad    italian_0         18
# 25          gorgonzola gnocchi    italian_0         18
# 26                 squid pasta    italian_0         18
# 27              gnocchi better    italian_0         18
# 28                time regular    italian_0         18
# 29           regular champagne    italian_0         18
# ...                        ...          ...        ...
# 30279                bev hills   italian_50      14481
# 30280  entertainment assistant   italian_50      14481
# 30281             coopers pale   italian_50      14481
# 30282                 pale ale   italian_50      14481
# 30283           tomato potatoe   italian_50      14484
# 30284             potatoe soup   italian_50      14484
# 30285              glass wines   italian_50      14484
# 30286                 il formo   italian_50      14485
# 30287              formo caldo   italian_50      14485
# 30288                 mi piace   italian_50      14485
# 30289          town pasadena..   italian_50      14485
# 30290          chicken alfredo   italian_50      14485
# 30291            chicken penne   italian_50      14485
# 30292               pink sauce   italian_50      14485
# 30293                  oil dip   italian_50      14485
# 30294       saturday afternoon   italian_50      14485
# 30295               okay staff   italian_50      14485
# 30296              food.. hehe   italian_50      14485
# 30297           hills location   italian_50      14486
# 30298             dinning area   italian_50      14486
# 30299        reason whatsoever   italian_50      14486
# 30300                 il forno   italian_50      14486
# 30301              forno caldo   italian_50      14486
# 30302               warm bread   italian_50      14488
# 30303              veg options   italian_50      14488
# 30304         coworkers inform   italian_50      14488
# 30305             cognac sauce   italian_50      14488
# 30306       chicken parmagiana   italian_50      14489
# 30307             oven chicken   italian_50      14489
# 30308           homemade bread   italian_50      14489
#
#                                                 sentence  sentence_id
# 0      I recommend the fried goat cheese for an appet...            3
# 1                                     Excellent service.            0
# 2                    The pasta was el dente and perfect.            3
# 3                                          CRAPPY owner!            1
# 4      Love this place ... we chose to dine here on a...            0
# 5      Love this place ... we chose to dine here on a...            0
# 6      Love this place ... we chose to dine here on a...            0
# 7      Not crowded at all on a Tuesday night before a...            2
# 8      Not crowded at all on a Tuesday night before a...            2
# 9      Not crowded at all on a Tuesday night before a...            2
# 10     The homemade bread is terrific along with the ...            0
# 11     The homemade bread is terrific along with the ...            0
# 12     I had the Gorgonzola chicken & my BF had the l...            1
# 13     I had the Pasta alla norcina and the Zuppa del...            0
# 14     I had the Pasta alla norcina and the Zuppa del...            0
# 15     I had the Pasta alla norcina and the Zuppa del...            0
# 16     I had the Pasta alla norcina and the Zuppa del...            0
# 17     I had the Pasta alla norcina and the Zuppa del...            0
# 18     The pasta alla norcina was made with tomato sa...            4
# 19     The pasta alla norcina was made with tomato sa...            4
# 20     The pasta alla norcina was made with tomato sa...            4
# 21     The pasta alla norcina was made with tomato sa...            4
# 22     The pasta fagioli was thick and comforting and...            2
# 23     There was then some lame excuse about how they...            2
# 24     We ordered a goat cheese salad that was highly...            6
# 25     We ordered a goat cheese salad that was highly...            6
# 26     We ordered a goat cheese salad that was highly...            6
# 27     Both pastas were great- I liked the gnocchi be...            8
# 28                  This time regular champagne arrived.           10
# 29                  This time regular champagne arrived.           10
# ...                                                  ...          ...
# 30279  It's a good Italian meal for the price, especi...            2
# 30280  It's a good Italian meal for the price, especi...            2
# 30281  One interesting thing i'd like to point out is...            3
# 30282  One interesting thing i'd like to point out is...            3
# 30283    Awesome steak sandwich and tomato potatoe soup.            1
# 30284    Awesome steak sandwich and tomato potatoe soup.            1
# 30285        Nice by the glass wines as well as bottles.            3
# 30286  I like my il formo caldo italian restaurant in...            0
# 30287  I like my il formo caldo italian restaurant in...            0
# 30288  I like my il formo caldo italian restaurant in...            0
# 30289  I like my il formo caldo italian restaurant in...            0
# 30290  I like my il formo caldo italian restaurant in...            0
# 30291  I like my il formo caldo italian restaurant in...            0
# 30292  I like my il formo caldo italian restaurant in...            0
# 30293  I like my il formo caldo italian restaurant in...            0
# 30294  there is usually not a wait there at all durin...            1
# 30295  they also have an okay staff for service..but ...            2
# 30296  they also have an okay staff for service..but ...            2
# 30297  The prices are very reasonable, especially for...            2
# 30298  The dinning area is quaint, but if there are m...            3
# 30299  There is no reason whatsoever to drive far to ...            5
# 30300  There is no reason whatsoever to drive far to ...            5
# 30301  There is no reason whatsoever to drive far to ...            5
# 30302             Yummy warm bread, the best bruschetta.            0
# 30303  As a vegetarian, their veg options were pretty...            1
# 30304  My coworkers inform me the chicken in cognac s...            2
# 30305  My coworkers inform me the chicken in cognac s...            2
# 30306  I was a little concerned when the menu didn't ...            2
# 30307  I was a little concerned when the menu didn't ...            2
# 30308  I especially have to suggest the homemade brea...            3
#
# [30309 rows x 5 columns]
# reducing 1
# reducing 2
# reducing 3
# finally
# 0
#  ['0', '\n']
# 814
#  ['814\n']
# 	/biz/il-capriccio-on-vermont-los-angeles	Il Capriccio on Vermont
#  ['', '/biz/il-capriccio-on-vermont-los-angeles', 'Il Capriccio on Vermont\n']
# 1
#  ['1', '\n']
# 714
#  ['714\n']
# 	/biz/pomodoro-trattoria-los-angeles-2	Pomodoro Trattoria
#  ['', '/biz/pomodoro-trattoria-los-angeles-2', 'Pomodoro Trattoria\n']
# 2
#  ['2', '\n']
# 488
#  ['488\n']
# 	/biz/speranza-los-angeles	Speranza
#  ['', '/biz/speranza-los-angeles', 'Speranza\n']
# 3
#  ['3', '\n']
# 298
#  ['298\n']
# 	/biz/frankies-los-angeles-2	Frankies
#  ['', '/biz/frankies-los-angeles-2', 'Frankies\n']
# 4
#  ['4', '\n']
# 1001
#  ['1001\n']
# 	/biz/the-factory-kitchen-los-angeles	The Factory Kitchen
#  ['', '/biz/the-factory-kitchen-los-angeles', 'The Factory Kitchen\n']
# 5
#  ['5', '\n']
# 1382
#  ['1382\n']
# 	/biz/drago-centro-los-angeles	DRAGO Centro
#  ['', '/biz/drago-centro-los-angeles', 'DRAGO Centro\n']
# 6
#  ['6', '\n']
# 455
#  ['455\n']
# 	/biz/pizzicotto-los-angeles	Pizzicotto
#  ['', '/biz/pizzicotto-los-angeles', 'Pizzicotto\n']
# 7
#  ['7', '\n']
# 562
#  ['562\n']
# 	/biz/spumoni-restaurant-sherman-oaks	Spumoni Restaurant
#  ['', '/biz/spumoni-restaurant-sherman-oaks', 'Spumoni Restaurant\n']
# 8
#  ['8', '\n']
# 726
#  ['726\n']
# 	/biz/fabiolus-cucina-hollywood	Fabiolus Cucina
#  ['', '/biz/fabiolus-cucina-hollywood', 'Fabiolus Cucina\n']
# 9
#  ['9', '\n']
# 879
#  ['879\n']
# 	/biz/gales-pasadena	Gales
#  ['', '/biz/gales-pasadena', 'Gales\n']
# 10
#  ['10', '\n']
# 637
#  ['637\n']
# 	/biz/madeo-restaurant-los-angeles-3	Madeo Restaurant
#  ['', '/biz/madeo-restaurant-los-angeles-3', 'Madeo Restaurant\n']
# 11
#  ['11', '\n']
# 391
#  ['391\n']
# 	/biz/gusto-los-angeles	Gusto
#  ['', '/biz/gusto-los-angeles', 'Gusto\n']
# 12
#  ['12', '\n']
# 259
#  ['259\n']
# 	/biz/centanni-trattoria-burbank	Centanni Trattoria
#  ['', '/biz/centanni-trattoria-burbank', 'Centanni Trattoria\n']
# 13
#  ['13', '\n']
# 249
#  ['249\n']
# 	/biz/cafe-angelino-los-angeles	Cafe Angelino
#  ['', '/biz/cafe-angelino-los-angeles', 'Cafe Angelino\n']
# 14
#  ['14', '\n']
# 677
#  ['677\n']
# 	/biz/la-tavolata-artesia	La Tavolata
#  ['', '/biz/la-tavolata-artesia', 'La Tavolata\n']
# 15
#  ['15', '\n']
# 775
#  ['775\n']
# 	/biz/raffaello-ristorante-san-pedro	Raffaello Ristorante
#  ['', '/biz/raffaello-ristorante-san-pedro', 'Raffaello Ristorante\n']
# 16
#  ['16', '\n']
# 877
#  ['877\n']
# 	/biz/jon-and-vinnys-los-angeles	Jon & Vinnys
#  ['', '/biz/jon-and-vinnys-los-angeles', 'Jon & Vinnys\n']
# 17
#  ['17', '\n']
# 641
#  ['641\n']
# 	/biz/ca-del-sole-toluca-lake-2	Ca Del Sole
#  ['', '/biz/ca-del-sole-toluca-lake-2', 'Ca Del Sole\n']
# 18
#  ['18', '\n']
# 423
#  ['423\n']
# 	/biz/locanda-veneta-los-angeles	Locanda Veneta
#  ['', '/biz/locanda-veneta-los-angeles', 'Locanda Veneta\n']
# 19
#  ['19', '\n']
# 260
#  ['260\n']
# 	/biz/enzo-and-angela-los-angeles-2	Enzo & Angela
#  ['', '/biz/enzo-and-angela-los-angeles-2', 'Enzo & Angela\n']
# 20
#  ['20', '\n']
# 344
#  ['344\n']
# 	/biz/italys-little-kitchen-los-angeles	Italys Little Kitchen
#  ['', '/biz/italys-little-kitchen-los-angeles', 'Italys Little Kitchen\n']
# 21
#  ['21', '\n']
# 1344
#  ['1344\n']
# 	/biz/c-and-o-cucina-marina-del-rey	C & O Cucina
#  ['', '/biz/c-and-o-cucina-marina-del-rey', 'C & O Cucina\n']
# 22
#  ['22', '\n']
# 434
#  ['434\n']
# 	/biz/chi-spacca-los-angeles	Chi Spacca
#  ['', '/biz/chi-spacca-los-angeles', 'Chi Spacca\n']
# 23
#  ['23', '\n']
# 214
#  ['214\n']
# 	/biz/spartina-los-angeles	Spartina
#  ['', '/biz/spartina-los-angeles', 'Spartina\n']
# 24
#  ['24', '\n']
# 247
#  ['247\n']
# 	/biz/ancora-cucina-italiana-tarzana	Ancora Cucina Italiana
#  ['', '/biz/ancora-cucina-italiana-tarzana', 'Ancora Cucina Italiana\n']
# 25
#  ['25', '\n']
# 275
#  ['275\n']
# 	/biz/north-italia-santa-monica-3	North Italia
#  ['', '/biz/north-italia-santa-monica-3', 'North Italia\n']
# 26
#  ['26', '\n']
# 495
#  ['495\n']
# 	/biz/romano-cucina-sunset-beach-2	Romano Cucina
#  ['', '/biz/romano-cucina-sunset-beach-2', 'Romano Cucina\n']
# 27
#  ['27', '\n']
# 207
#  ['207\n']
# 	/biz/palmeri-ristorante-los-angeles	Palmeri Ristorante
#  ['', '/biz/palmeri-ristorante-los-angeles', 'Palmeri Ristorante\n']
# 28
#  ['28', '\n']
# 333
#  ['333\n']
# 	/biz/brunos-santa-monica	Brunos
#  ['', '/biz/brunos-santa-monica', 'Brunos\n']
# 29
#  ['29', '\n']
# 950
#  ['950\n']
# 	/biz/trattoria-amici-glendale-2	Trattoria Amici
#  ['', '/biz/trattoria-amici-glendale-2', 'Trattoria Amici\n']
# 30
#  ['30', '\n']
# 372
#  ['372\n']
# 	/biz/via-veneto-santa-monica	Via Veneto
#  ['', '/biz/via-veneto-santa-monica', 'Via Veneto\n']
# 31
#  ['31', '\n']
# 276
#  ['276\n']
# 	/biz/novecento-pasta-and-grill-culver-city	Novecento Pasta & Grill
#  ['', '/biz/novecento-pasta-and-grill-culver-city', 'Novecento Pasta & Grill\n']
# 32
#  ['32', '\n']
# 265
#  ['265\n']
# 	/biz/adagio-ristorante-woodland-hills	Adagio Ristorante
#  ['', '/biz/adagio-ristorante-woodland-hills', 'Adagio Ristorante\n']
# 33
#  ['33', '\n']
# 238
#  ['238\n']
# 	/biz/buon-gusto-ristorante-mission-hills	Buon Gusto Ristorante
#  ['', '/biz/buon-gusto-ristorante-mission-hills', 'Buon Gusto Ristorante\n']
# 34
#  ['34', '\n']
# 303
#  ['303\n']
# 	/biz/divina-cucina-montrose	Divina Cucina
#  ['', '/biz/divina-cucina-montrose', 'Divina Cucina\n']
# 35
#  ['35', '\n']
# 464
#  ['464\n']
# 	/biz/il-tramezzino-beverly-hills-beverly-hills	Il Tramezzino - Beverly Hills
#  ['', '/biz/il-tramezzino-beverly-hills-beverly-hills', 'Il Tramezzino - Beverly Hills\n']
# 36
#  ['36', '\n']
# 394
#  ['394\n']
# 	/biz/via-alloro-beverly-hills-2	Via Alloro
#  ['', '/biz/via-alloro-beverly-hills-2', 'Via Alloro\n']
# 37
#  ['37', '\n']
# 271
#  ['271\n']
# 	/biz/la-cava-san-fernando-valley	La Cava
#  ['', '/biz/la-cava-san-fernando-valley', 'La Cava\n']
# 38
#  ['38', '\n']
# 237
#  ['237\n']
# 	/biz/betos-simi-valley	Betos
#  ['', '/biz/betos-simi-valley', 'Betos\n']
# 39
#  ['39', '\n']
# 529
#  ['529\n']
# 	/biz/ago-restaurant-west-hollywood	AGO Restaurant
#  ['', '/biz/ago-restaurant-west-hollywood', 'AGO Restaurant\n']
# 40
#  ['40', '\n']
# 434
#  ['434\n']
# 	/biz/vino-and-cucina-long-beach	Vino & Cucina
#  ['', '/biz/vino-and-cucina-long-beach', 'Vino & Cucina\n']
# 41
#  ['41', '\n']
# 254
#  ['254\n']
# 	/biz/trastevere-hollywood-2	Trastevere
#  ['', '/biz/trastevere-hollywood-2', 'Trastevere\n']
# 42
#  ['42', '\n']
# 279
#  ['279\n']
# 	/biz/picarellis-cucina-italiana-long-beach-3	Picarellis Cucina Italiana
#  ['', '/biz/picarellis-cucina-italiana-long-beach-3', 'Picarellis Cucina Italiana\n']
# 43
#  ['43', '\n']
# 422
#  ['422\n']
# 	/biz/la-scala-beverly-hills-2	La Scala
#  ['', '/biz/la-scala-beverly-hills-2', 'La Scala\n']
# 44
#  ['44', '\n']
# 361
#  ['361\n']
# 	/biz/il-ristorante-di-giorgio-baldi-santa-monica	Il Ristorante di Giorgio Baldi
#  ['', '/biz/il-ristorante-di-giorgio-baldi-santa-monica', 'Il Ristorante di Giorgio Baldi\n']
# 45
#  ['45', '\n']
# 245
#  ['245\n']
# 	/biz/mangiamo-ristorante-and-bar-manhattan-beach	Mangiamo Ristorante & Bar
#  ['', '/biz/mangiamo-ristorante-and-bar-manhattan-beach', 'Mangiamo Ristorante & Bar\n']
# 46
#  ['46', '\n']
# 351
#  ['351\n']
# 	/biz/capo-santa-monica	Capo
#  ['', '/biz/capo-santa-monica', 'Capo\n']
# 47
#  ['47', '\n']
# 412
#  ['412\n']
# 	/biz/valentino-santa-monica	Valentino
#  ['', '/biz/valentino-santa-monica', 'Valentino\n']
# 48
#  ['48', '\n']
# 222
#  ['222\n']
# 	/biz/locanda-portofino-santa-monica-2	Locanda Portofino
#  ['', '/biz/locanda-portofino-santa-monica-2', 'Locanda Portofino\n']
# 49
#  ['49', '\n']
# 213
#  ['213\n']
# 	/biz/the-bottle-inn-hermosa-hermosa-beach	The Bottle Inn Hermosa
#  ['', '/biz/the-bottle-inn-hermosa-hermosa-beach', 'The Bottle Inn Hermosa\n']
# 50
#  ['50', '\n']
# 325
#  ['325\n']
# 	/biz/francos-italian-restaurant-cypress	Francos Italian Restaurant
#  ['', '/biz/francos-italian-restaurant-cypress', 'Francos Italian Restaurant\n']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-b760678b2746> in <module>()
# ----> 1 runGene('italian')
#
# <ipython-input-17-47e46f7edaf6> in runGene(geneName)
#      15     getFreq(geneName + '.csv', 'test.csv')
#      16     toJson('test.csv', 'json.json', geneName)
# ---> 17     getresult('json.json', sys.stdout)
#      18
#      19 if DEFINES_ONLY == False:
#
# <ipython-input-14-518d4a77b264> in getresult(inputjson, outputfile)
#      24     for restaurant in d: #[0:5]:
#      25         outputfile.write('\n')
# ---> 26         outputfile.write(dictIdName[restaurant['restaurantId']])
#      27 #         outputfile.write(restaurant['restaurantName'] + '\n')
#      28         likes=[]
#
# KeyError: 'italian_18'

# %%
getresult('groupby_resuaurant_phrase2Grams_review.json', open('chinese_result.txt', 'w'))
# Out:
# 0
#  ['0', '\n']
# 221
#  ['221\n']
# 	/biz/the-new-moon-los-angeles	The New Moon
#  ['', '/biz/the-new-moon-los-angeles', 'The New Moon\n']
# 1
#  ['1', '\n']
# 242
#  ['242\n']
# 	/biz/northern-cafe-los-angeles	Northern Cafe
#  ['', '/biz/northern-cafe-los-angeles', 'Northern Cafe\n']
# 2
#  ['2', '\n']
# 251
#  ['251\n']
# 	/biz/pauls-kitchen-los-angeles	Pauls Kitchen
#  ['', '/biz/pauls-kitchen-los-angeles', 'Pauls Kitchen\n']
# 3
#  ['3', '\n']
# 201
#  ['201\n']
# 	/biz/shin-beijing-los-angeles	Shin Beijing
#  ['', '/biz/shin-beijing-los-angeles', 'Shin Beijing\n']
# 4
#  ['4', '\n']
# 396
#  ['396\n']
# 	/biz/house-of-joy-chinese-restaurant-glendale	House of Joy Chinese Restaurant
#  ['', '/biz/house-of-joy-chinese-restaurant-glendale', 'House of Joy Chinese Restaurant\n']
# 5
#  ['5', '\n']
# 316
#  ['316\n']
# 	/biz/jin-jiang-restaurant-los-angeles	Jin Jiang Restaurant
#  ['', '/biz/jin-jiang-restaurant-los-angeles', 'Jin Jiang Restaurant\n']
# 6
#  ['6', '\n']
# 239
#  ['239\n']
# 	/biz/chyn-king-los-angeles	Chyn King
#  ['', '/biz/chyn-king-los-angeles', 'Chyn King\n']
# 7
#  ['7', '\n']
# 317
#  ['317\n']
# 	/biz/phoenix-inn-chinese-cuisine-los-angeles	Phoenix Inn Chinese Cuisine
#  ['', '/biz/phoenix-inn-chinese-cuisine-los-angeles', 'Phoenix Inn Chinese Cuisine\n']
# 8
#  ['8', '\n']
# 337
#  ['337\n']
# 	/biz/ixlb-dimsum-eats-los-angeles-2	ixlb DimSum Eats
#  ['', '/biz/ixlb-dimsum-eats-los-angeles-2', 'ixlb DimSum Eats\n']
# 9
#  ['9', '\n']
# 255
#  ['255\n']
# 	/biz/cheng-du-restaurant-los-angeles	Cheng Du Restaurant
#  ['', '/biz/cheng-du-restaurant-los-angeles', 'Cheng Du Restaurant\n']
# 10
#  ['10', '\n']
# 898
#  ['898\n']
# 	/biz/won-kok-restaurant-los-angeles	Won Kok Restaurant
#  ['', '/biz/won-kok-restaurant-los-angeles', 'Won Kok Restaurant\n']
# 11
#  ['11', '\n']
# 308
#  ['308\n']
# 	/biz/rice-wok-studio-city	Rice Wok
#  ['', '/biz/rice-wok-studio-city', 'Rice Wok\n']
# 12
#  ['12', '\n']
# 202
#  ['202\n']
# 	/biz/hot-wok-north-hollywood	Hot Wok
#  ['', '/biz/hot-wok-north-hollywood', 'Hot Wok\n']
# 13
#  ['13', '\n']
# 248
#  ['248\n']
# 	/biz/little-palace-glendale	Little Palace
#  ['', '/biz/little-palace-glendale', 'Little Palace\n']
# 14
#  ['14', '\n']
# 273
#  ['273\n']
# 	/biz/wok-on-the-wild-side-inglewood	Wok On The Wild Side
#  ['', '/biz/wok-on-the-wild-side-inglewood', 'Wok On The Wild Side\n']
# 15
#  ['15', '\n']
# 291
#  ['291\n']
# 	/biz/hop-li-seafood-restaurant-los-angeles	Hop Li Seafood Restaurant
#  ['', '/biz/hop-li-seafood-restaurant-los-angeles', 'Hop Li Seafood Restaurant\n']
# 16
#  ['16', '\n']
# 1677
#  ['1677\n']
# 	/biz/mamas-lu-dumpling-house-monterey-park-4	Mamas Lu Dumpling House
#  ['', '/biz/mamas-lu-dumpling-house-monterey-park-4', 'Mamas Lu Dumpling House\n']
# 17
#  ['17', '\n']
# 301
#  ['301\n']
# 	/biz/mandarin-kitchen-los-angeles	Mandarin Kitchen
#  ['', '/biz/mandarin-kitchen-los-angeles', 'Mandarin Kitchen\n']
# 18
#  ['18', '\n']
# 343
#  ['343\n']
# 	/biz/chinese-deli-t-and-d-north-hollywood-2	Chinese Deli T & D
#  ['', '/biz/chinese-deli-t-and-d-north-hollywood-2', 'Chinese Deli T & D\n']
# 19
#  ['19', '\n']
# 302
#  ['302\n']
# 	/biz/lao-sze-chuan-glendale-5	Lao Sze Chuan
#  ['', '/biz/lao-sze-chuan-glendale-5', 'Lao Sze Chuan\n']
# 20
#  ['20', '\n']
# 402
#  ['402\n']
# 	/biz/twin-dragon-chinese-restaurant-los-angeles	Twin Dragon Chinese Restaurant
#  ['', '/biz/twin-dragon-chinese-restaurant-los-angeles', 'Twin Dragon Chinese Restaurant\n']
# 21
#  ['21', '\n']
# 225
#  ['225\n']
# 	/biz/green-tea-house-los-angeles	Green Tea House
#  ['', '/biz/green-tea-house-los-angeles', 'Green Tea House\n']
# 22
#  ['22', '\n']
# 228
#  ['228\n']
# 	/biz/ping-pong-chinese-cuisine-encino-3	Ping Pong Chinese Cuisine
#  ['', '/biz/ping-pong-chinese-cuisine-encino-3', 'Ping Pong Chinese Cuisine\n']
# 23
#  ['23', '\n']
# 403
#  ['403\n']
# 	/biz/hop-woo-bbq-and-seafood-restaurant-la-los-angeles	Hop Woo BBQ & Seafood Restaurant - LA
#  ['', '/biz/hop-woo-bbq-and-seafood-restaurant-la-los-angeles', 'Hop Woo BBQ & Seafood Restaurant - LA\n']
# 24
#  ['24', '\n']
# 808
#  ['808\n']
# 	/biz/maos-kitchen-venice	Maos Kitchen
#  ['', '/biz/maos-kitchen-venice', 'Maos Kitchen\n']
# 25
#  ['25', '\n']
# 256
#  ['256\n']
# 	/biz/regent-china-inn-los-angeles	Regent China Inn
#  ['', '/biz/regent-china-inn-los-angeles', 'Regent China Inn\n']
# 26
#  ['26', '\n']
# 329
#  ['329\n']
# 	/biz/grandview-palace-pasadena	Grandview Palace
#  ['', '/biz/grandview-palace-pasadena', 'Grandview Palace\n']
# 27
#  ['27', '\n']
# 533
#  ['533\n']
# 	/biz/new-moon-montrose	New Moon
#  ['', '/biz/new-moon-montrose', 'New Moon\n']
# 28
#  ['28', '\n']
# 286
#  ['286\n']
# 	/biz/dragon-street-chinese-north-hollywood-2	Dragon Street Chinese
#  ['', '/biz/dragon-street-chinese-north-hollywood-2', 'Dragon Street Chinese\n']
# 29
#  ['29', '\n']
# 292
#  ['292\n']
# 	/biz/silver-palace-chinese-restaurant-whittier-3	Silver Palace Chinese Restaurant
#  ['', '/biz/silver-palace-chinese-restaurant-whittier-3', 'Silver Palace Chinese Restaurant\n']
# 30
#  ['30', '\n']
# 201
#  ['201\n']
# 	/biz/healthy-wok-sherman-oaks	Healthy Wok
#  ['', '/biz/healthy-wok-sherman-oaks', 'Healthy Wok\n']
# 31
#  ['31', '\n']
# 466
#  ['466\n']
# 	/biz/szechuan-impression-alhambra-3	Szechuan Impression
#  ['', '/biz/szechuan-impression-alhambra-3', 'Szechuan Impression\n']
# 32
#  ['32', '\n']
# 302
#  ['302\n']
# 	/biz/chinese-delight-north-hollywood	Chinese Delight
#  ['', '/biz/chinese-delight-north-hollywood', 'Chinese Delight\n']
# 33
#  ['33', '\n']
# 333
#  ['333\n']
# 	/biz/golden-phoenix-lakewood	Golden Phoenix
#  ['', '/biz/golden-phoenix-lakewood', 'Golden Phoenix\n']
# 34
#  ['34', '\n']
# 339
#  ['339\n']
# 	/biz/chin-chin-beverly-hills	Chin Chin
#  ['', '/biz/chin-chin-beverly-hills', 'Chin Chin\n']
# 35
#  ['35', '\n']
# 415
#  ['415\n']
# 	/biz/ws-china-bistro-redondo-beach	Ws China Bistro
#  ['', '/biz/ws-china-bistro-redondo-beach', 'Ws China Bistro\n']
# 36
#  ['36', '\n']
# 235
#  ['235\n']
# 	/biz/golden-hunan-chinese-restaurant-northridge	Golden Hunan Chinese Restaurant
#  ['', '/biz/golden-hunan-chinese-restaurant-northridge', 'Golden Hunan Chinese Restaurant\n']
# 37
#  ['37', '\n']
# 367
#  ['367\n']
# 	/biz/hui-tou-xiang-san-gabriel	Hui Tou Xiang
#  ['', '/biz/hui-tou-xiang-san-gabriel', 'Hui Tou Xiang\n']
# 38
#  ['38', '\n']
# 282
#  ['282\n']
# 	/biz/jj-chinese-express-long-beach	JJ Chinese Express
#  ['', '/biz/jj-chinese-express-long-beach', 'JJ Chinese Express\n']
# 39
#  ['39', '\n']
# 220
#  ['220\n']
# 	/biz/wacky-wok-venice	Wacky Wok
#  ['', '/biz/wacky-wok-venice', 'Wacky Wok\n']
# 40
#  ['40', '\n']
# 267
#  ['267\n']
# 	/biz/hong-kong-express-westminster-3	Hong Kong Express
#  ['', '/biz/hong-kong-express-westminster-3', 'Hong Kong Express\n']
# 41
#  ['41', '\n']
# 659
#  ['659\n']
# 	/biz/chengdu-taste-alhambra	Chengdu Taste
#  ['', '/biz/chengdu-taste-alhambra', 'Chengdu Taste\n']
# 42
#  ['42', '\n']
# 371
#  ['371\n']
# 	/biz/golden-wall-la-mirada	Golden Wall
#  ['', '/biz/golden-wall-la-mirada', 'Golden Wall\n']
# 43
#  ['43', '\n']
# 301
#  ['301\n']
# 	/biz/yang-chow-pasadena	Yang Chow
#  ['', '/biz/yang-chow-pasadena', 'Yang Chow\n']
# 44
#  ['44', '\n']
# 234
#  ['234\n']
# 	/biz/tasty-kitchen-gardena	Tasty Kitchen
#  ['', '/biz/tasty-kitchen-gardena', 'Tasty Kitchen\n']
# 45
#  ['45', '\n']
# 492
#  ['492\n']
# 	/biz/seafood-port-chinese-restaurant-torrance	Seafood Port Chinese Restaurant
#  ['', '/biz/seafood-port-chinese-restaurant-torrance', 'Seafood Port Chinese Restaurant\n']
# 46
#  ['46', '\n']
# 232
#  ['232\n']
# 	/biz/harlams-kitchen-rosemead-2	Harlams Kitchen
#  ['', '/biz/harlams-kitchen-rosemead-2', 'Harlams Kitchen\n']
# 47
#  ['47', '\n']
# 373
#  ['373\n']
# 	/biz/seafood-town-chinese-restaurant-torrance	Seafood Town Chinese Restaurant
#  ['', '/biz/seafood-town-chinese-restaurant-torrance', 'Seafood Town Chinese Restaurant\n']
# 48
#  ['48', '\n']
# 599
#  ['599\n']
# 	/biz/fortune-cookies-restaurant-los-alamitos	Fortune Cookies Restaurant
#  ['', '/biz/fortune-cookies-restaurant-los-alamitos', 'Fortune Cookies Restaurant\n']
# 49
#  ['49', '\n']
# 262
#  ['262\n']
# 	/biz/the-great-wall-chinese-restaurant-reseda	The Great Wall Chinese Restaurant
#  ['', '/biz/the-great-wall-chinese-restaurant-reseda', 'The Great Wall Chinese Restaurant\n']
# 50
#  ['50', '\n']
# 211
#  ['211\n']
# 	/biz/phoenix-food-boutique-south-pasadena	Phoenix Food Boutique
#  ['', '/biz/phoenix-food-boutique-south-pasadena', 'Phoenix Food Boutique\n']

# %%
customerRestaurant('/biz/king-szechuan-palace-jersey-city', 'King Szechuan Palace')
# Out:
# 1
# 0 King Szechuan Palace
# 0
# 20
# 40
# 60
# 80
#                    phrase restaurantId  review_id  \
# 0          pork intestine   customer_0          0
# 1            intestine w.   customer_0          0
# 2            chili pepper   customer_0          0
# 3          pork intestine   customer_0          0
# 4            intestine w.   customer_0          0
# 5            chili pepper   customer_0          0
# 6            chinese food   customer_0          1
# 7               mapo tofu   customer_0          1
# 8            chinese food   customer_0          2
# 9           szechuan food   customer_0          2
# 10             food items   customer_0          2
# 11            pot recipes   customer_0          3
# 12         soup dumplings   customer_0          3
# 13                sub par   customer_0          4
# 14          par dumplings   customer_0          4
# 15              min drive   customer_0          4
# 16         soup dumplings   customer_0          5
# 17       delivery chinese   customer_0          6
# 18           chinese food   customer_0          6
# 19            jersey city   customer_0          6
# 20           pepper steak   customer_0          6
# 21              shrimp lo   customer_0          6
# 22                lo mein   customer_0          6
# 23           krab rangoon   customer_0          6
# 24              shrimp lo   customer_0          6
# 25                lo mein   customer_0          6
# 26         price.the krab   customer_0          6
# 27           krab rangoon   customer_0          6
# 28           cream cheese   customer_0          6
# 29         please forgive   customer_0          7
# ..                    ...          ...        ...
# 211           tender beef   customer_0         83
# 212               mau pau   customer_0         83
# 213              pau tofu   customer_0         83
# 214         spicy wontons   customer_0         83
# 215              pay cash   customer_0         84
# 216          chinese food   customer_0         85
# 217         king szechuan   customer_0         85
# 218       chinese around-   customer_0         86
# 219            tests- egg   customer_0         86
# 220             egg rolls   customer_0         86
# 221             mill take   customer_0         87
# 222         delivery time   customer_0         88
# 223          delivery etc   customer_0         88
# 224       delivery driver   customer_0         88
# 225         food delivery   customer_0         88
# 226        chinese option   customer_0         89
# 227           jersey city   customer_0         89
# 228         legit attempt   customer_0         89
# 229         szechuan food   customer_0         89
# 230               dan dan   customer_0         89
# 231           dan noodles   customer_0         89
# 232         spicy noodles   customer_0         89
# 233        spicy cucumber   customer_0         89
# 234             time yelp   customer_0         90
# 235           yelp reader   customer_0         90
# 236      chinese delivery   customer_0         90
# 237        delivery place   customer_0         90
# 238  szechuan peppercorns   customer_0         90
# 239       szechuan spices   customer_0         91
# 240           tongue numb   customer_0         91
#
#                                               sentence  sentence_id
# 0    Dry Sauteed Pork Intestine w. Dried Red Chili ...            1
# 1    Dry Sauteed Pork Intestine w. Dried Red Chili ...            1
# 2    Dry Sauteed Pork Intestine w. Dried Red Chili ...            1
# 3    Dry Sauteed Pork Intestine w. Dried Red Chili ...            3
# 4    Dry Sauteed Pork Intestine w. Dried Red Chili ...            3
# 5    Dry Sauteed Pork Intestine w. Dried Red Chili ...            3
# 6                It's actually authentic Chinese food.            1
# 7          I ordered the mapo tofu and it was so good!            2
# 8    Recently moved nearby and this is the first an...            0
# 9    There is a wide variety of both Americanized a...            2
# 10   There is a wide variety of both Americanized a...            2
# 11     Great dry pot recipes, wontons, soup dumplings.            2
# 12     Great dry pot recipes, wontons, soup dumplings.            2
# 13   waited an hour and a half for sub par dumpling...            0
# 14   waited an hour and a half for sub par dumpling...            0
# 15   Positive they forgot about it because it was d...            2
# 16                    The best soup dumplings in town.            0
# 17   This will be our go-to for delivery Chinese fo...            0
# 18   This will be our go-to for delivery Chinese fo...            0
# 19   This will be our go-to for delivery Chinese fo...            0
# 20   Husband had the pepper steak and an order of v...            3
# 21          I had the shrimp lo mein and krab Rangoon.            5
# 22          I had the shrimp lo mein and krab Rangoon.            5
# 23          I had the shrimp lo mein and krab Rangoon.            5
# 24   The shrimp lo mein was very good, lots of shri...            6
# 25   The shrimp lo mein was very good, lots of shri...            6
# 26   The portions were also good for the price.The ...            7
# 27   The portions were also good for the price.The ...            7
# 28   The portions were also good for the price.The ...            7
# 29   I'm not going to go off on them angrily, thoug...            0
# ..                                                 ...          ...
# 211  So far I have had 4 different types of "Double...            5
# 212  The vegetarian Mau Pau Tofu is soft, silky, an...            7
# 213  The vegetarian Mau Pau Tofu is soft, silky, an...            7
# 214  The spicy wontons are a little doughy, but sti...            8
# 215           DO NOT ORDER ONLINE AND PAY CASH!!!!!!!!            3
# 216  I've got some pretty terrible Chinese food aro...            1
# 217  I've got some pretty terrible Chinese food aro...            1
# 218  Easily the best Chinese around- we've tried th...            0
# 219  Passed the simplest of tests- egg rolls and th...            2
# 220  Passed the simplest of tests- egg rolls and th...            2
# 221  The reviews made me think I might have found a...            0
# 222  After ordering online I called to check delive...            0
# 223  I had to call back 4 more times checking on st...            2
# 224  The delivery driver never showed up, meaning t...            5
# 225  The delivery driver never showed up, meaning t...            5
# 226  Finally, we have real Szechuan and a great Chi...            0
# 227  Finally, we have real Szechuan and a great Chi...            0
# 228  I haven't been there but I've had them through...            1
# 229  I haven't been there but I've had them through...            1
# 230  So far I've had successful versions of double ...            2
# 231  So far I've had successful versions of double ...            2
# 232  So far I've had successful versions of double ...            2
# 233  So far I've had successful versions of double ...            2
# 234               Long time yelp reader, first review.            0
# 235               Long time yelp reader, first review.            0
# 236  We live in Hoboken and have been looking for a...            1
# 237  We live in Hoboken and have been looking for a...            1
# 238  First of all I love Szechuan food...specifical...            3
# 239       This place uses traditional Szechuan spices.            2
# 240  That's right, you know that spice which makes ...            3
#
# [241 rows x 5 columns]
# reducing 1
# reducing 2
# reducing 3
# finally
# 0
#  ['0\n']
# 300
#  ['300\n']
# 	/biz/king-szechuan-palace-jersey-city	King Szechuan Palace
#  ['', '/biz/king-szechuan-palace-jersey-city', 'King Szechuan Palace\n']
#
# King Szechuan Palace
#
# What the Guests loved Most:
# chinese food
# mapo tofu
# jersey city
# soup dumplings
# food delivery
# friday night
# delivery person
# seamless reviews
# delivery man
#
# What nedd to be improved:
# customer service
#
#
# __main__
